# %% [markdown]
# <a href="https://colab.research.google.com/github/nampy3/n_ml/blob/master/data_visualization_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer
import matplotlib.pyplot as plt

# %%
# Make the request and check object type
r = requests.get('https://en.wikipedia.org/wiki/Machine_learning')

# %%
# Extract HTML from Response object and print
html = r.text

# %%
# Create a BeautifulSoup object from the HTML
soup = BeautifulSoup(html, "html5lib")

# %%
# Get the text out of the soup and print it
text = soup.get_text()

# %%
# Create tokenizer
tokenizer = RegexpTokenizer('\w+')
# Create tokens
word_list = tokenizer.tokenize(text)
# Create freq dist and plot
words = nltk.FreqDist(word_list)
words
# Out:
# FreqDist({'Machine': 71,
#           'learning': 225,
#           'Wikipedia': 6,
#           'document': 2,
#           'documentElement': 2,
#           'className': 2,
#           'replace': 1,
#           's': 20,
#           'client': 2,
#           'nojs': 1,
#           '1client': 1,
#           'js': 2,
#           '2': 38,
#           'RLCONF': 1,
#           'wgCanonicalNamespace': 1,
#           'wgCanonicalSpecialPageName': 1,
#           '1': 59,
#           'wgNamespaceNumber': 1,
#           '0': 36,
#           'wgPageName': 1,
#           'Machine_learning': 4,
#           'wgTitle': 1,
#           'wgCurRevisionId': 1,
#           '902812327': 3,
#           'wgRevisionId': 1,
#           'wgArticleId': 1,
#           '233488': 2,
#           'wgIsArticle': 1,
#           'wgIsRedirect': 1,
#           'wgAction': 1,
#           'view': 2,
#           'wgUserName': 1,
#           'null': 1,
#           'wgUserGroups': 1,
#           'wgCategories': 1,
# ...

# %%
words.plot(20)

# %%
from collections  import Counter
c= Counter(words)

# %%
top=c.most_common(20)
x,y=zip(*top)
plt.pie(y,labels=x, shadow=True, autopct="%d%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7fef8b2699e8>,
# ...
#  [Text(1.008344661103386, 0.4395919066865291, 'the'),
#   Text(0.45707828750005347, 1.0005395739779703, 'of'),
#   Text(-0.2108056467322543, 1.0796114946154456, 'learning'),
#   Text(-0.7625686486165114, 0.7927730167880259, 'a'),
#   Text(-1.0615593356892372, 0.2882564427918753, 'and'),
#   Text(-1.0649562453319361, -0.27544181877214163, 'to'),
#   Text(-0.8514200864868334, -0.6964796022330828, 'in'),
#   Text(-0.5965061839740803, -0.9242187903741629, 'is'),
#   Text(-0.3572426695074405, -1.0403738150699477, 'machine'),
#   Text(-0.1190823343429469, -1.093535274989991, 'data'),
#   Text(0.11322326899099927, -1.0941574344485312, 'that'),
#   Text(0.32503500716214023, -1.0508816508623164, 'Machine'),
#   Text(0.5034540115121231, -0.9780255918391662, 'are'),
#   Text(0.6522706699970499, -0.8857443045606332, '1'),
#   Text(0.783525147329065, -0.7720675770312903, 'algorithms'),
#   Text(0.8909565875623471, -0.6451328228196563, 'for'),
# ...
