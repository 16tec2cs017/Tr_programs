# %% [markdown]
# # Computer Vision

# %%
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %% [markdown]
# #
# *  1 - Means image in same color channel --GRB or --RGB
# *  0 - Means image in Gray Scale ( B & W)
# *  -1- Means image in transparent mode.

# %%
#image reading
img=cv2.imread("art-artistic-background-1328891.jpg", 1)
img1=cv2.imread("art-artistic-background-1328891.jpg", 0)
img2=cv2.imread("art-artistic-background-1328891.jpg", -1)
img
# Out:
# array([[[16, 11,  2],
#         [16, 11,  2],
#         [16, 10,  3],
#         ...,
#         [ 6,  1,  0],
#         [ 6,  0,  1],
#         [ 7,  1,  2]],
#
#        [[16, 11,  2],
#         [16, 11,  2],
#         [16, 10,  3],
#         ...,
#         [ 6,  1,  0],
#         [ 6,  0,  1],
#         [ 7,  1,  2]],
#
#        [[16, 10,  3],
#         [16, 10,  3],
#         [17, 11,  4],
#         ...,
#         [ 6,  1,  0],
#         [ 6,  0,  1],
#         [ 7,  1,  2]],
#
#        ...,
#
#        [[12,  8,  3],
#         [14, 10,  5],
#         [14, 10,  5],
#         ...,
#         [ 9,  3,  0],
#         [ 9,  2,  0],
#         [ 9,  2,  0]],
#
#        [[12,  8,  3],
#         [13,  9,  4],
#         [13,  9,  4],
#         ...,
#         [10,  4,  0],
#         [10,  3,  0],
#         [10,  3,  0]],
#
#        [[11,  7,  2],
#         [13,  9,  4],
#         [13,  9,  4],
#         ...,
#         [10,  4,  0],
#         [11,  4,  1],
#         [11,  4,  1]]], dtype=uint8)

# %%
#print shape
img.shape
# Out:
# (2823, 4000, 3)

# %%
#type
type(img)
# Out:
# numpy.ndarray

# %%
#to display image
cv2_imshow(img)

# %%
#to display image
cv2_imshow(img1)

# %%
cv2_imshow(img[0:400,0:400])
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FBD84E8C748>

# %%
x,y,z=cv2.split(img)

# %%
cv2_imshow(x[0:400,0:400])
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FBD84E8C7F0>

# %%
cv2_imshow(y[0:400,0:400])
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FBD84E8C908>

# %%
cv2_imshow(z[0:400,0:400])
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FBD84E76C50>

# %%
myimg=np.zeros((512,512))

# %%
cv2_imshow(myimg)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FBD84E8C550>

# %%
#to draw a line in image
cv2.line(myimg,(0,0),(200,230),(156,134,125), 3)
cv2.rectangle(myimg,(50,50),(200,230),(156,134,225), -1)
cv2_imshow(myimg)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FBD84E95048>
