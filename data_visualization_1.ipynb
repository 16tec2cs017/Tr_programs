# %% [markdown]
# <a href="https://colab.research.google.com/github/nampy3/n_ml/blob/master/data_visualization_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data2.csv')
df
# Out:
#    Student_name  Marks  Age     Contact  Study_Hours
# 0          ASIF     65   20  9658446985            6
# 1      KHURSHID     14   23  9658446986            5
# 2       MUZAMIL     25   25  9658446987            9
# 3       TANVEER     95   22  9658446988            3
# 4          ASIF     74   21  9658446989            5
# 5         ADDIL     35   19  9658446990            4
# 6        KUCHAY     34   25  9658446991            6
# 7      ISHTIYAQ     95   18  9658446992            8
# 8         NASIR     44   21  9658446993            3
# 9         MAJID     66   23  9658446994            9
# 10        GULAM     35   26  9658446995            4
# 11       SHABIR     77   25  9658446996            3
# 12         ASIF     54   28  9658446997            4
# 13     KHURSHID     88   14  9658446998            6
# 14      MUZAMIL     85   19  9658446999            4
# 15      TANVEER     66   17  9658447000            9
# 16         ASIF     44   16  9658447001            2
# ...

# %%
plt.pie(df.Marks, labels=df.Student_name,shadow=True, autopct='%1.1f%%')
plt.show()

# %%
plt.pie(df.Study_Hours, labels=df.Student_name,shadow=True, autopct='%1.1f%%')
plt.show()

# %%
plt.pie(df.Study_Hours, labels=df.Student_name,shadow=True, autopct='%1.1f%%')
plt.show()
